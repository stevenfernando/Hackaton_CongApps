# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pregunta 1:

# %%
asamblea_2023 = pd.read_excel('Hackaton/Diputados_para_la_eleccion_de_asamblea.xlsx', index_col=2)
del asamblea_2023["Descripción del Municipio"]
del asamblea_2023["Descripción de la Comuna/Localidad/Corregimiento"]

# %%
# Función para normalizar caracteres en una celda
def normalize_text(text):
    if isinstance(text, str):
        return unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('utf-8')
    else:
        return text

asamblea_2023.head(5)
# Out:
#                              Descripción de la Corporación/Cargo  \
# Descripción del Departamento
# AMAZONAS                                                ASAMBLEA
# AMAZONAS                                                ASAMBLEA
# AMAZONAS                                                ASAMBLEA
# AMAZONAS                                                ASAMBLEA
# AMAZONAS                                                ASAMBLEA
#
#                              Descripción de la Circunscripción  \
# Descripción del Departamento
# AMAZONAS                                         DEPARTAMENTAL
# AMAZONAS                                         DEPARTAMENTAL
# AMAZONAS                                         DEPARTAMENTAL
# AMAZONAS                                         DEPARTAMENTAL
# AMAZONAS                                         DEPARTAMENTAL
#
#                               Código Tipo de Agrupación Política  \
# Descripción del Departamento
# ...

# %%
# Concatenar las columnas "Primer Nombre," "Segundo Nombre," "Primer Apellido," y "Segundo Apellido"
asamblea_2023.loc[:,'candidatos'] = asamblea_2023[['Primer Nombre', 'Segundo Nombre', 'Primer Apellido', 'Segundo Apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)

# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_2023 = asamblea_2023[['candidatos']]

# %%
candidatos_2023.head(5)
# Out:
#                                                 candidatos
# Descripción del Departamento
# AMAZONAS                      HECTOR FABIO OSORIO RIVILLAS
# AMAZONAS                       JUAN CARLOS MARTINEZ MORENO
# AMAZONAS                           JOSE LUIS NIETO BOLIVAR
# AMAZONAS                            JOHN ARVEY ABT VALERIO
# AMAZONAS                                   NORMA RODRIGUEZ

# %%
data={'Candidatos':candidatos_2023['candidatos'],'Elección 2003':candidatos_2023['candidatos'], 'Elección 2007':candidatos_2023['candidatos'], 'Elección 2011':candidatos_2023['candidatos'], 'Elección 2015':candidatos_2023['candidatos'], 'Elección 2019':candidatos_2023['candidatos'], 'Elección 2023':candidatos_2023['candidatos']}
dfinal=pd.DataFrame(data)

# %% [markdown]
# **2003**

# %%
eleccion_asamblea_2003 = pd.read_csv("Hackaton/Asamblea/2003_asamblea.dta.csv")
eleccion1_asamblea_2003 = eleccion_asamblea_2003[['departamento','municipio']]
eleccion_asamblea_2003.loc[:, 'candidatos 2003'] = eleccion_asamblea_2003[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_asamblea_2003 = eleccion_asamblea_2003[['candidatos 2003']]
candidatos1_asamblea_2003 = pd.concat([candidatos_asamblea_2003, eleccion1_asamblea_2003], join = 'outer', axis = 1)


eleccion_alcaldia_2003 = pd.read_csv("Hackaton/Alcaldia/2003_alcaldia.dta.csv")
eleccion1_alcaldia_2003 = eleccion_alcaldia_2003[['departamento','municipio']]
eleccion_alcaldia_2003.loc[:, 'candidatos 2003'] = eleccion_alcaldia_2003[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_alcaldia_2003 = eleccion_alcaldia_2003[['candidatos 2003']]
candidatos1_alcaldia_2003 = pd.concat([candidatos_alcaldia_2003, eleccion1_alcaldia_2003], join = 'outer', axis = 1)


eleccion_gobernacion_2003 = pd.read_csv("Hackaton/Gobernación/2003_gobernacion.dta.csv")
eleccion1_gobernacion_2003 = eleccion_gobernacion_2003[['departamento','municipio']]
eleccion_gobernacion_2003.loc[:, 'candidatos 2003'] = eleccion_gobernacion_2003[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_gobernacion_2003 = eleccion_gobernacion_2003[['candidatos 2003']]
candidatos1_gobernacion_2003 = pd.concat([candidatos_gobernacion_2003, eleccion1_gobernacion_2003], join = 'outer', axis = 1)

# Aplica la normalización de caracteres a todo el DataFrame

eleccion_concejo_2003 = pd.read_csv("Hackaton/Concejo/2003_concejo.dta.csv", encoding='latin-1')
eleccion1_concejo_2003 = eleccion_concejo_2003[['departamento','municipio']]
eleccion_concejo_2003.loc[:, 'candidatos 2003'] = eleccion_concejo_2003[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_concejo_2003 = eleccion_concejo_2003[['candidatos 2003']]
candidatos1_concejo_2003 = pd.concat([candidatos_concejo_2003, eleccion1_concejo_2003], join = 'outer', axis = 1)

# %% [markdown]
# **2006**

# %%
eleccion_senado_2006 = pd.read_csv("Hackaton/Senado/2006_senado.dta.csv")
eleccion1_senado_2006 = eleccion_senado_2006[['departamento','municipio']]
eleccion_senado_2006.loc[:, 'candidatos 2006'] = eleccion_senado_2006[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_senado_2006 = eleccion_senado_2006[['candidatos 2006']]
candidatos1_senado_2006 = pd.concat([candidatos_senado_2006, eleccion1_senado_2006], join = 'outer', axis = 1)


eleccion_camara_2006 = pd.read_csv("Hackaton/Camara/2006_camara.dta.csv")
eleccion1_camara_2006 = eleccion_camara_2006[['departamento','municipio']]
eleccion_camara_2006.loc[:, 'candidatos 2006'] = eleccion_camara_2006[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_camara_2006 = eleccion_camara_2006[['candidatos 2006']]
candidatos1_camara_2006 = pd.concat([candidatos_camara_2006, eleccion1_camara_2006], join = 'outer', axis = 1)

# %% [markdown]
# **2007**

# %%
eleccion_asamblea_2007 = pd.read_csv("Hackaton/Asamblea/2007_asamblea.dta.csv")
eleccion1_asamblea_2007 = eleccion_asamblea_2007[['departamento','municipio']]
eleccion_asamblea_2007.loc[:, 'candidatos 2007'] = eleccion_asamblea_2007[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_asamblea_2007 = eleccion_asamblea_2007[['candidatos 2007']]
candidatos1_asamblea_2007 = pd.concat([candidatos_asamblea_2007, eleccion1_asamblea_2007], join = 'outer', axis = 1)


eleccion_alcaldia_2007 = pd.read_csv("Hackaton/Alcaldia/2007_alcaldia.dta.csv")
eleccion1_alcaldia_2007 = eleccion_alcaldia_2007[['departamento','municipio']]
eleccion_alcaldia_2007.loc[:, 'candidatos 2007'] = eleccion_alcaldia_2007[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_alcaldia_2007 = eleccion_alcaldia_2007[['candidatos 2007']]
candidatos1_alcaldia_2007 = pd.concat([candidatos_alcaldia_2007, eleccion1_alcaldia_2007], join = 'outer', axis = 1)


eleccion_gobernacion_2007 = pd.read_csv("Hackaton/Gobernación/2007_gobernacion.dta.csv")
eleccion1_gobernacion_2007 = eleccion_gobernacion_2007[['departamento','municipio']]
eleccion_gobernacion_2007.loc[:, 'candidatos 2007'] = eleccion_gobernacion_2007[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_gobernacion_2007 = eleccion_gobernacion_2007[['candidatos 2007']]
candidatos1_gobernacion_2007 = pd.concat([candidatos_gobernacion_2007, eleccion1_gobernacion_2007], join = 'outer', axis = 1)


eleccion_concejo_2007 = pd.read_csv("Hackaton/Concejo/2007_concejo.dta.csv")
eleccion1_concejo_2007 = eleccion_concejo_2007[['departamento','municipio']]
eleccion_concejo_2007.loc[:, 'candidatos 2007'] = eleccion_concejo_2007[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_concejo_2007 = eleccion_concejo_2007[['candidatos 2007']]
candidatos1_concejo_2007 = pd.concat([candidatos_concejo_2007, eleccion1_concejo_2007], join = 'outer', axis = 1)

# %% [markdown]
# **2010**

# %%
eleccion_senado_2010 = pd.read_csv("Hackaton/Senado/2010_senado.dta.csv")
eleccion1_senado_2010 = eleccion_senado_2010[['departamento','municipio']]
eleccion_senado_2010.loc[:, 'candidatos 2010'] = eleccion_senado_2010[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_senado_2010 = eleccion_senado_2010[['candidatos 2010']]
candidatos1_senado_2010 = pd.concat([candidatos_senado_2010, eleccion1_senado_2010], join = 'outer', axis = 1)


eleccion_camara_2010 = pd.read_csv("Hackaton/Camara/2010_camara.dta.csv")
eleccion1_camara_2010 = eleccion_camara_2010[['departamento','municipio']]
eleccion_camara_2010.loc[:, 'candidatos 2010'] = eleccion_camara_2010[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_camara_2010 = eleccion_camara_2010[['candidatos 2010']]
candidatos1_camara_2010 = pd.concat([candidatos_camara_2010, eleccion1_camara_2010], join = 'outer', axis = 1)

# %% [markdown]
# **2011**

# %%
eleccion_asamblea_2011 = pd.read_csv("Hackaton/Asamblea/2011_asamblea.dta.csv")
eleccion1_asamblea_2011 = eleccion_asamblea_2011[['departamento','municipio']]
eleccion_asamblea_2011.loc[:, 'candidatos 2011'] = eleccion_asamblea_2011[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_asamblea_2011 = eleccion_asamblea_2011[['candidatos 2011']]
candidatos1_asamblea_2011 = pd.concat([candidatos_asamblea_2011, eleccion1_asamblea_2011], join = 'outer', axis = 1)


eleccion_alcaldia_2011 = pd.read_csv("Hackaton/Alcaldia/2007_alcaldia.dta.csv")
eleccion1_alcaldia_2011 = eleccion_alcaldia_2011[['departamento','municipio']]
eleccion_alcaldia_2011.loc[:, 'candidatos 2011'] = eleccion_alcaldia_2011[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_alcaldia_2011 = eleccion_alcaldia_2011[['candidatos 2011']]
candidatos1_alcaldia_2011 = pd.concat([candidatos_alcaldia_2011, eleccion1_alcaldia_2011], join = 'outer', axis = 1)


eleccion_gobernacion_2011 = pd.read_csv("Hackaton/Gobernación/2011_gobernacion.dta.csv")
eleccion1_gobernacion_2011 = eleccion_gobernacion_2011[['departamento','municipio']]
eleccion_gobernacion_2011.loc[:, 'candidatos 2011'] = eleccion_gobernacion_2011[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_gobernacion_2011 = eleccion_gobernacion_2011[['candidatos 2011']]
candidatos1_gobernacion_2011 = pd.concat([candidatos_gobernacion_2011, eleccion1_gobernacion_2011], join = 'outer', axis = 1)


eleccion_concejo_2011 = pd.read_csv("Hackaton/Concejo/2011_concejo.dta.csv")
eleccion1_concejo_2011 = eleccion_concejo_2011[['departamento','municipio']]
eleccion_concejo_2011.loc[:, 'candidatos 2011'] = eleccion_concejo_2011[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_concejo_2011 = eleccion_concejo_2011[['candidatos 2011']]
candidatos1_concejo_2011 = pd.concat([candidatos_concejo_2011, eleccion1_concejo_2011], join = 'outer', axis = 1)

# %% [markdown]
# **2014**

# %%
eleccion_senado_2014 = pd.read_csv("Hackaton/Senado/2014_senado.dta.csv")
eleccion1_senado_2014 = eleccion_senado_2014[['departamento','municipio']]
eleccion_senado_2014.loc[:, 'candidatos 2014'] = eleccion_senado_2014[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_senado_2014 = eleccion_senado_2014[['candidatos 2014']]
candidatos1_senado_2014 = pd.concat([candidatos_senado_2014, eleccion1_senado_2014], join = 'outer', axis = 1)


eleccion_camara_2014 = pd.read_csv("Hackaton/Camara/2014_camara.dta.csv")
eleccion1_camara_2014 = eleccion_camara_2014[['departamento','municipio']]
eleccion_camara_2014.loc[:, 'candidatos 2014'] = eleccion_camara_2014[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_camara_2014 = eleccion_camara_2014[['candidatos 2014']]
candidatos1_camara_2014 = pd.concat([candidatos_camara_2014, eleccion1_camara_2014], join = 'outer', axis = 1)

# %% [markdown]
# **2015**

# %%
eleccion_asamblea_2015 = pd.read_csv("Hackaton/Asamblea/2015_asamblea.dta.csv")
eleccion1_asamblea_2015 = eleccion_asamblea_2015[['departamento','municipio']]
eleccion_asamblea_2015.loc[:, 'candidatos 2015'] = eleccion_asamblea_2015[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_asamblea_2015 = eleccion_asamblea_2015[['candidatos 2015']]
candidatos1_asamblea_2015 = pd.concat([candidatos_asamblea_2015, eleccion1_asamblea_2015], join = 'outer', axis = 1)


eleccion_alcaldia_2015 = pd.read_csv("Hackaton/Alcaldia/2015_alcaldia.dta.csv")
eleccion1_alcaldia_2015 = eleccion_alcaldia_2015[['departamento','municipio']]
eleccion_alcaldia_2015.loc[:, 'candidatos 2015'] = eleccion_alcaldia_2015[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_alcaldia_2015 = eleccion_alcaldia_2015[['candidatos 2015']]
candidatos1_alcaldia_2015 = pd.concat([candidatos_alcaldia_2015, eleccion1_alcaldia_2015], join = 'outer', axis = 1)


eleccion_gobernacion_2015 = pd.read_csv("Hackaton/Gobernación/2015_gobernacion.dta.csv", encoding='latin-1')
eleccion1_gobernacion_2015 = eleccion_gobernacion_2015[['departamento','municipio']]
eleccion_gobernacion_2015.loc[:, 'candidatos 2015'] = eleccion_gobernacion_2015[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_gobernacion_2015 = eleccion_gobernacion_2015[['candidatos 2015']]
candidatos1_gobernacion_2015 = pd.concat([candidatos_gobernacion_2015, eleccion1_gobernacion_2015], join = 'outer', axis = 1)


eleccion_concejo_2015 = pd.read_csv("Hackaton/Concejo/2015_concejo.dta.csv")
eleccion1_concejo_2015 = eleccion_concejo_2015[['departamento','municipio']]
eleccion_concejo_2015.loc[:, 'candidatos 2015'] = eleccion_concejo_2015[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_concejo_2015 = eleccion_concejo_2015[['candidatos 2015']]
candidatos1_concejo_2015 = pd.concat([candidatos_concejo_2015, eleccion1_concejo_2015], join = 'outer', axis = 1)

# %% [markdown]
# **2018**

# %%
eleccion_senado_2018 = pd.read_csv("Hackaton/Senado/2018_senado.dta.csv")
eleccion1_senado_2018 = eleccion_senado_2018[['departamento','municipio']]
eleccion_senado_2018.loc[:, 'candidatos 2018'] = eleccion_senado_2018[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_senado_2018 = eleccion_senado_2018[['candidatos 2018']]
candidatos1_senado_2018 = pd.concat([candidatos_senado_2018, eleccion1_senado_2018], join = 'outer', axis = 1)


eleccion_camara_2018 = pd.read_csv("Hackaton/Camara/2018_camara.dta.csv")
eleccion1_camara_2018 = eleccion_camara_2018[['departamento','municipio']]
eleccion_camara_2018.loc[:, 'candidatos 2018'] = eleccion_camara_2018[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_camara_2018 = eleccion_camara_2018[['candidatos 2018']]
candidatos1_camara_2018 = pd.concat([candidatos_camara_2018, eleccion1_camara_2018], join = 'outer', axis = 1)

# %% [markdown]
# **2019**

# %%
eleccion_asamblea_2019 = pd.read_csv("Hackaton/Asamblea/2019_asamblea.dta.csv")
eleccion1_asamblea_2019 = eleccion_asamblea_2019[['departamento','municipio']]
eleccion_asamblea_2019.loc[:, 'candidatos 2019'] = eleccion_asamblea_2019[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_asamblea_2019 = eleccion_asamblea_2019[['candidatos 2019']]
candidatos1_asamblea_2019 = pd.concat([candidatos_asamblea_2019, eleccion1_asamblea_2019], join = 'outer', axis = 1)


eleccion_alcaldia_2019 = pd.read_csv("Hackaton/Alcaldia/2019_alcaldia.dta.csv")
eleccion1_alcaldia_2019 = eleccion_alcaldia_2019[['departamento','municipio']]
eleccion_alcaldia_2019.loc[:, 'candidatos 2019'] = eleccion_alcaldia_2019[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_alcaldia_2019 = eleccion_alcaldia_2019[['candidatos 2019']]
candidatos1_alcaldia_2019 = pd.concat([candidatos_alcaldia_2019, eleccion1_alcaldia_2019], join = 'outer', axis = 1)


eleccion_gobernacion_2019 = pd.read_csv("Hackaton/Gobernación/2019_gobernacion.dta.csv")
eleccion1_gobernacion_2019 = eleccion_gobernacion_2019[['departamento','municipio']]
eleccion_gobernacion_2019.loc[:, 'candidatos 2019'] = eleccion_gobernacion_2019[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_gobernacion_2019 = eleccion_gobernacion_2019[['candidatos 2019']]
candidatos1_gobernacion_2019 = pd.concat([candidatos_gobernacion_2019, eleccion1_gobernacion_2019], join = 'outer', axis = 1)


eleccion_concejo_2019 = pd.read_csv("Hackaton/Concejo/2019_concejo.dta.csv")
eleccion1_concejo_2019 = eleccion_concejo_2019[['departamento','municipio']]
eleccion_concejo_2019.loc[:, 'candidatos 2019'] = eleccion_concejo_2019[['nombres', 'primer_apellido', 'segundo_apellido']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Crear un nuevo DataFrame llamado "candidatos" que contiene solo la columna "candidatos"
candidatos_concejo_2019 = eleccion_concejo_2019[['candidatos 2019']]
candidatos1_concejo_2019 = pd.concat([candidatos_concejo_2019, eleccion1_concejo_2019], join = 'outer', axis = 1)

# %% [markdown]
# **Diseños de los datasets**

# %% [markdown]
# **Asamblea**

# %%
list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_asamblea= dfinal.copy()

list1 = candidatos1_asamblea_2003['candidatos 2003'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_asamblea['Elección 2003']= dfinal_asamblea['Elección 2003'].replace([dfinal_asamblea['Elección 2003'][i]], 'yes')  
    else:  
        dfinal_asamblea['Elección 2003']= dfinal_asamblea['Elección 2003'].replace([dfinal_asamblea['Elección 2003'][i]], 'no')

list2 = candidatos1_asamblea_2007['candidatos 2007'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_asamblea['Elección 2007']= dfinal_asamblea['Elección 2007'].replace([dfinal_asamblea['Elección 2007'][i]], 'yes')  
    else:  
        dfinal_asamblea['Elección 2007']= dfinal_asamblea['Elección 2007'].replace([dfinal_asamblea['Elección 2007'][i]], 'no')

list3 = candidatos1_asamblea_2011['candidatos 2011'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_asamblea['Elección 2011']= dfinal_asamblea['Elección 2011'].replace([dfinal_asamblea['Elección 2011'][i]], 'yes')  
    else:  
        dfinal_asamblea['Elección 2011']= dfinal_asamblea['Elección 2011'].replace([dfinal_asamblea['Elección 2011'][i]], 'no')

list4 = candidatos1_asamblea_2015['candidatos 2015'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list4:
        dfinal_asamblea['Elección 2015']= dfinal_asamblea['Elección 2015'].replace([dfinal_asamblea['Elección 2015'][i]], 'yes')  
    else:  
        dfinal_asamblea['Elección 2015']= dfinal_asamblea['Elección 2015'].replace([dfinal_asamblea['Elección 2015'][i]], 'no')

list5 = candidatos1_asamblea_2019['candidatos 2019'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list5:
        dfinal_asamblea['Elección 2019']= dfinal_asamblea['Elección 2019'].replace([dfinal_asamblea['Elección 2019'][i]], 'yes')  
    else:  
        dfinal_asamblea['Elección 2019']= dfinal_asamblea['Elección 2019'].replace([dfinal_asamblea['Elección 2019'][i]], 'no')

for i in np.arange(0, len(list0)):
    dfinal_asamblea['Elección 2023']= dfinal_asamblea['Elección 2023'].replace([dfinal_asamblea['Elección 2023'][i]], 'yes')

# %%
dfinal_asamblea.head(15)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_asamblea['Candidatos']).index(a)
c = 0
years = [2019, 2015, 2011, 2007, 2003]
for i in years:
    if dfinal_asamblea['Elección {}'.format(i)][(b)]== "yes":
        c +=1

if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de asamblea de:".format(a))
        
for i in years:
    if dfinal_asamblea['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Alcaldia**

# %%
list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_alcaldia= dfinal.copy()

list1 = candidatos1_alcaldia_2003['candidatos 2003'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_alcaldia['Elección 2003']= dfinal_alcaldia['Elección 2003'].replace([dfinal_alcaldia['Elección 2003'][i]], 'yes')  
    else:  
        dfinal_alcaldia['Elección 2003']= dfinal_alcaldia['Elección 2003'].replace([dfinal_alcaldia['Elección 2003'][i]], 'no')

list2 = candidatos1_alcaldia_2007['candidatos 2007'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_alcaldia['Elección 2007']= dfinal_alcaldia['Elección 2007'].replace([dfinal_alcaldia['Elección 2007'][i]], 'yes')  
    else:  
        dfinal_alcaldia['Elección 2007']= dfinal_alcaldia['Elección 2007'].replace([dfinal_alcaldia['Elección 2007'][i]], 'no')

list3 = candidatos1_alcaldia_2011['candidatos 2011'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_alcaldia['Elección 2011']= dfinal_alcaldia['Elección 2011'].replace([dfinal_alcaldia['Elección 2011'][i]], 'yes')  
    else:  
        dfinal_alcaldia['Elección 2011']= dfinal_alcaldia['Elección 2011'].replace([dfinal_alcaldia['Elección 2011'][i]], 'no')

list4 = candidatos1_alcaldia_2015['candidatos 2015'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list4:
        dfinal_alcaldia['Elección 2015']= dfinal_alcaldia['Elección 2015'].replace([dfinal_alcaldia['Elección 2015'][i]], 'yes')  
    else:  
        dfinal_alcaldia['Elección 2015']= dfinal_alcaldia['Elección 2015'].replace([dfinal_alcaldia['Elección 2015'][i]], 'no')

list5 = candidatos1_alcaldia_2019['candidatos 2019'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list5:
        dfinal_alcaldia['Elección 2019']= dfinal_alcaldia['Elección 2019'].replace([dfinal_alcaldia['Elección 2019'][i]], 'yes')  
    else:  
        dfinal_alcaldia['Elección 2019']= dfinal_alcaldia['Elección 2019'].replace([dfinal_alcaldia['Elección 2019'][i]], 'no')

for i in np.arange(0, len(list0)):
    dfinal_alcaldia['Elección 2023']= dfinal_alcaldia['Elección 2023'].replace([dfinal_alcaldia['Elección 2023'][i]], 'no')

# %%
dfinal_alcaldia.head(20)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_alcaldia['Candidatos']).index(a)
c = 0
years = [2019, 2015, 2011, 2007, 2003]
for i in years:
    if dfinal_alcaldia['Elección {}'.format(i)][(b)]== "yes":
        c +=1

if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de alcaldia de:".format(a))
        
for i in years:
    if dfinal_alcaldia['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Gobernación**

# %%
list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_gobernacion= dfinal.copy()

list1 = candidatos1_gobernacion_2003['candidatos 2003'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_gobernacion['Elección 2003']= dfinal_gobernacion['Elección 2003'].replace([dfinal_gobernacion['Elección 2003'][i]], 'yes')  
    else:  
        dfinal_gobernacion['Elección 2003']= dfinal_gobernacion['Elección 2003'].replace([dfinal_gobernacion['Elección 2003'][i]], 'no')

list2 = candidatos1_gobernacion_2007['candidatos 2007'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_gobernacion['Elección 2007']= dfinal_gobernacion['Elección 2007'].replace([dfinal_gobernacion['Elección 2007'][i]], 'yes')  
    else:  
        dfinal_gobernacion['Elección 2007']= dfinal_gobernacion['Elección 2007'].replace([dfinal_gobernacion['Elección 2007'][i]], 'no')

list3 = candidatos1_gobernacion_2011['candidatos 2011'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_gobernacion['Elección 2011']= dfinal_gobernacion['Elección 2011'].replace([dfinal_gobernacion['Elección 2011'][i]], 'yes')  
    else:  
        dfinal_gobernacion['Elección 2011']= dfinal_gobernacion['Elección 2011'].replace([dfinal_gobernacion['Elección 2011'][i]], 'no')

list4 = candidatos1_gobernacion_2015['candidatos 2015'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list4:
        dfinal_gobernacion['Elección 2015']= dfinal_gobernacion['Elección 2015'].replace([dfinal_gobernacion['Elección 2015'][i]], 'yes')  
    else:  
        dfinal_gobernacion['Elección 2015']= dfinal_gobernacion['Elección 2015'].replace([dfinal_gobernacion['Elección 2015'][i]], 'no')

list5 = candidatos1_gobernacion_2019['candidatos 2019'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list5:
        dfinal_gobernacion['Elección 2019']= dfinal_gobernacion['Elección 2019'].replace([dfinal_gobernacion['Elección 2019'][i]], 'yes')  
    else:  
        dfinal_gobernacion['Elección 2019']= dfinal_gobernacion['Elección 2019'].replace([dfinal_gobernacion['Elección 2019'][i]], 'no')

for i in np.arange(0, len(list0)):
    dfinal_gobernacion['Elección 2023']= dfinal_gobernacion['Elección 2023'].replace([dfinal_gobernacion['Elección 2023'][i]], 'no')

# %%
dfinal_gobernacion.head(40)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_gobernacion['Candidatos']).index(a)
c = 0
years = [2019, 2015, 2011, 2007, 2003]
for i in years:
    if dfinal_gobernacion['Elección {}'.format(i)][(b)]== "yes":
        c +=1

if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de gobernador de:".format(a))
        
for i in years:
    if dfinal_gobernacion['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Concejo**

# %%
list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_concejo= dfinal.copy()

list1 = candidatos1_concejo_2003['candidatos 2003'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_concejo['Elección 2003']= dfinal_concejo['Elección 2003'].replace([dfinal_concejo['Elección 2003'][i]], 'yes')  
    else:  
        dfinal_concejo['Elección 2003']= dfinal_concejo['Elección 2003'].replace([dfinal_concejo['Elección 2003'][i]], 'no')

list2 = candidatos1_concejo_2007['candidatos 2007'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_concejo['Elección 2007']= dfinal_concejo['Elección 2007'].replace([dfinal_concejo['Elección 2007'][i]], 'yes')  
    else:  
        dfinal_concejo['Elección 2007']= dfinal_concejo['Elección 2007'].replace([dfinal_concejo['Elección 2007'][i]], 'no')

list3 = candidatos1_concejo_2011['candidatos 2011'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_concejo['Elección 2011']= dfinal_concejo['Elección 2011'].replace([dfinal_concejo['Elección 2011'][i]], 'yes')  
    else:  
        dfinal_concejo['Elección 2011']= dfinal_concejo['Elección 2011'].replace([dfinal_concejo['Elección 2011'][i]], 'no')

list4 = candidatos1_concejo_2015['candidatos 2015'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list4:
        dfinal_concejo['Elección 2015']= dfinal_concejo['Elección 2015'].replace([dfinal_concejo['Elección 2015'][i]], 'yes')  
    else:  
        dfinal_concejo['Elección 2015']= dfinal_concejo['Elección 2015'].replace([dfinal_concejo['Elección 2015'][i]], 'no')

list5 = candidatos1_concejo_2019['candidatos 2019'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list5:
        dfinal_concejo['Elección 2019']= dfinal_concejo['Elección 2019'].replace([dfinal_concejo['Elección 2019'][i]], 'yes')  
    else:  
        dfinal_concejo['Elección 2019']= dfinal_concejo['Elección 2019'].replace([dfinal_concejo['Elección 2019'][i]], 'no')

for i in np.arange(0, len(list0)):
    dfinal_concejo['Elección 2023']= dfinal_concejo['Elección 2023'].replace([dfinal_concejo['Elección 2023'][i]], 'no')

# %%
dfinal_concejo.head(40)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_concejo['Candidatos']).index(a)
c = 0
years = [2019, 2015, 2011, 2007, 2003]
for i in years:
    if dfinal_concejo['Elección {}'.format(i)][(b)]== "yes":
        c +=1

if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de Concejo de:".format(a))
        
for i in years:
    if dfinal_concejo['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Camara**

# %%
data2={'Candidatos':candidatos_2023['candidatos'],'Elección 2006':candidatos_2023['candidatos'], 'Elección 2010':candidatos_2023['candidatos'], 'Elección 2014':candidatos_2023['candidatos'], 'Elección 2018':candidatos_2023['candidatos']}
dfinal2=pd.DataFrame(data2)

list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_camara= dfinal2.copy()

list1 = candidatos1_camara_2006['candidatos 2006'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_camara['Elección 2006']= dfinal_camara['Elección 2006'].replace([dfinal_camara['Elección 2006'][i]], 'yes')  
    else:  
        dfinal_camara['Elección 2006']= dfinal_camara['Elección 2006'].replace([dfinal_camara['Elección 2006'][i]], 'no')

list2 = candidatos1_camara_2010['candidatos 2010'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_camara['Elección 2010']= dfinal_camara['Elección 2010'].replace([dfinal_camara['Elección 2010'][i]], 'yes')  
    else:  
        dfinal_camara['Elección 2010']= dfinal_camara['Elección 2010'].replace([dfinal_camara['Elección 2010'][i]], 'no')

list3 = candidatos1_camara_2014['candidatos 2014'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_camara['Elección 2014']= dfinal_camara['Elección 2014'].replace([dfinal_camara['Elección 2014'][i]], 'yes')  
    else:  
        dfinal_camara['Elección 2014']= dfinal_camara['Elección 2014'].replace([dfinal_camara['Elección 2014'][i]], 'no')

list4 = candidatos1_camara_2018['candidatos 2018'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list5:
        dfinal_camara['Elección 2018']= dfinal_camara['Elección 2018'].replace([dfinal_camara['Elección 2018'][i]], 'yes')  
    else:  
        dfinal_camara['Elección 2018']= dfinal_camara['Elección 2018'].replace([dfinal_camara['Elección 2018'][i]], 'no')

# %%
dfinal_camara.head(20)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_camara['Candidatos']).index(a)
c = 0
years = [2018, 2014, 2010, 2006]
for i in years:
    if dfinal_camara['Elección {}'.format(i)][(b)]== "yes":
        c +=1

if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de Camara de:".format(a))
        
for i in years:
    if dfinal_camara['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Senado**

# %%
list0 = candidatos_2023['candidatos'].values.tolist()
dfinal_senado= dfinal2.copy()

list1 = candidatos1_senado_2006['candidatos 2006'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list1:
        dfinal_senado['Elección 2006']= dfinal_senado['Elección 2006'].replace([dfinal_senado['Elección 2006'][i]], 'yes')  
    else:  
        dfinal_senado['Elección 2006']= dfinal_senado['Elección 2006'].replace([dfinal_senado['Elección 2006'][i]], 'no')

list2 = candidatos1_senado_2010['candidatos 2010'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list2:
        dfinal_senado['Elección 2010']= dfinal_senado['Elección 2010'].replace([dfinal_senado['Elección 2010'][i]], 'yes')  
    else:  
        dfinal_senado['Elección 2010']= dfinal_senado['Elección 2010'].replace([dfinal_senado['Elección 2010'][i]], 'no')

list3 = candidatos1_senado_2014['candidatos 2014'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list3:
        dfinal_senado['Elección 2014']= dfinal_senado['Elección 2014'].replace([dfinal_senado['Elección 2014'][i]], 'yes')  
    else:  
        dfinal_senado['Elección 2014']= dfinal_senado['Elección 2014'].replace([dfinal_senado['Elección 2014'][i]], 'no')

list4 = candidatos1_senado_2018['candidatos 2018'].values.tolist()
for i in np.arange(0, len(list0)):
    if list0[i] in list4:
        dfinal_senado['Elección 2018']= dfinal_senado['Elección 2018'].replace([dfinal_senado['Elección 2018'][i]], 'yes')  
    else:  
        dfinal_senado['Elección 2018']= dfinal_senado['Elección 2018'].replace([dfinal_senado['Elección 2018'][i]], 'no')

# %%
dfinal_senado.head(20)

# %%
a = "HECTOR FABIO OSORIO RIVILLAS"
#a = "LUIS ANGEL PANTEVIS"
b = list(dfinal_senado['Candidatos']).index(a)
c = 0
years = [2018, 2014, 2010, 2006]
for i in years:
    if dfinal_senado['Elección {}'.format(i)][(b)]== "yes":
        c +=1

print()
if c == 0: 
    print("{} no ha participado previamente en esta elección".format(a))
else:
    print("{} ha participado en las elecciones de Senado de:".format(a))
        
for i in years:
    if dfinal_senado['Elección {}'.format(i)][(b)]== "yes":
        print("{}".format(i))

# %% [markdown]
# **Código Final, parte 1:**

# %%
a = "ARNOLDO ENRIQUE MARULANDA"
#a = "LUIS ANGEL PANTEVIS"
b_asamblea = list(dfinal_asamblea['Candidatos']).index(a)
b_as=0
b_senado = list(dfinal_senado['Candidatos']).index(a)
b_sen=0
b_alcaldia = list(dfinal_alcaldia['Candidatos']).index(a)
b_al=0
b_gobernacion = list(dfinal_gobernacion['Candidatos']).index(a)
b_gob =0
b_camara = list(dfinal_camara['Candidatos']).index(a)
b_cam =0
b_concejo = list(dfinal_concejo['Candidatos']).index(a)
b_con=0
c = 0
print("Nombre: {}".format(a))
years1 = [2019, 2015, 2011, 2007, 2003]
years2 = [2018, 2014, 2010, 2006]


for i in years1:
    if dfinal_asamblea['Elección {}'.format(i)][(b_asamblea)]== "yes":
        b_as +=1

if b_as != 0:
    print("ha participado en las elecciones de asamblea de:".format(a))
else:
    c+=1
    
for j in years1:
    if dfinal_asamblea['Elección {}'.format(j)][(b_asamblea)]== "yes":
        print("{}".format(j))


for i in years1:
    if dfinal_alcaldia['Elección {}'.format(i)][(b_alcaldia)]== "yes":
        b_al +=1

if b_al != 0: 
    print("ha participado en las elecciones de alcaldia de:".format(a))
else:
    c+=1

for i in years1:
    if dfinal_alcaldia['Elección {}'.format(i)][(b_alcaldia)]== "yes":
        print("{}".format(i))


for i in years1:
    if dfinal_concejo['Elección {}'.format(i)][(b_concejo)]== "yes":
        b_con +=1

if b_con != 0: 
    print("ha participado en las elecciones de concejo de:".format(a))
else:
    c+=1

for i in years1:
    if dfinal_concejo['Elección {}'.format(i)][(b_concejo)]== "yes":
        print("{}".format(i))


for i in years1:
    if dfinal_gobernacion['Elección {}'.format(i)][(b_gobernacion)]== "yes":
        b_gob +=1

if b_gob != 0: 
    print("ha participado en las elecciones de gobernación de:".format(a))
else:
    c+=1

for i in years1:
    if dfinal_gobernacion['Elección {}'.format(i)][(b_gobernacion)]== "yes":
        print("{}".format(i))


for i in years2:
    if dfinal_camara['Elección {}'.format(i)][(b_camara)]== "yes":
        b_cam +=1

if b_cam != 0: 
    print("ha participado en las elecciones de camara de:".format(a))
else:
    c+=1
    
for i in years2:
    if dfinal_camara['Elección {}'.format(i)][(b_camara)]== "yes":
        print("{}".format(i))


for i in years2:
    if dfinal_senado['Elección {}'.format(i)][(b_senado)]== "yes":
        b_sen +=1

if b_sen != 0: 
    print("participado en las elecciones de senado de:".format(a))
else:
    c+=1
    
for i in years2:
    if dfinal_senado['Elección {}'.format(i)][(b_senado)]== "yes":
        print("{}".format(i))


if c==6:
    print("{} No ha participado previamente en elecciones.".format(a))
# Out:
# Nombre: ARNOLDO ENRIQUE MARULANDA
# ha participado en las elecciones de asamblea de:
# 2011
# ha participado en las elecciones de alcaldia de:
# 2003
